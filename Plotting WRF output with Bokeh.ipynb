# %%
from bokeh.io import output_notebook, show

# %% [markdown]
# # Plotting WRF output with Bokeh
# I recently started a Bokeh tutorial, and I'm starting to think it's a great package. With its focus on the browser and its integration with javascript to make fast and interactive visualizations, it might really become a useful alternative to matplotlib. However, it is only just starting to implement tools for visualization of graphic data, and the documentation about this aspect is still a bit poor. So I decided to try and plot some WRF output data using Bokeh, perhaps it can be useful for others as well.
#
# Note that there is also Holoview and Geoview (which is also very new and poorly documented), but I wanted to keep it simple and stayed close to the Bokeh basics.

# %% [markdown]
# ### Setting up a map
# The first step is to set up a map. Basically, that boils down to opening an empty figure and putting on top of it a set of tiles that constitute the map. These tiles are taken from the web, for example from google earth or openstreetmap. These are referred to as Web Map Tile Service (WMTS). All these web services use the web mercator coordinate system, which roughly ranges from -20M to 20M meters (in fact I think they're not exactly meters, but let's ignore that for now) in both the west-east and the north-south direction.
#
# A number of WMTS links are readily available in Bokeh, other will need to be loaded using a specific URL. To produce an empty map, we can use:

# %%
from bokeh.plotting import figure
from bokeh.tile_providers import STAMEN_TERRAIN, STAMEN_TONER, STAMEN_TONER_LABELS, STAMEN_TONER_BACKGROUND

# Create a figure with a really large extent
bound = 20000000 # meters
fig = figure(tools='pan, wheel_zoom', x_range=(-bound, bound), y_range=(-bound, bound))

# Hide the axes and add the map tile to the plot
fig.axis.visible = False
fig.add_tile(STAMEN_TERRAIN)

show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="48d251a9-8782-4bf7-932f-0ddd5dc3627b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("48d251a9-8782-4bf7-932f-0ddd5dc3627b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '48d251a9-8782-4bf7-932f-0ddd5dc3627b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a37f7360-7888-4c10-ad22-750e32af28bc":{"roots":{"references":[{"attributes":{"plot":{"id":"f6969e02-9934-497c-b97f-185b01bfff0c","subtype":"Figure","type":"Plot"}},"id":"baee8ecd-7085-4020-a3d0-b26de7e5d942","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"f6969e02-9934-497c-b97f-185b01bfff0c","subtype":"Figure","type":"Plot"},"ticker":{"id":"05131b25-6073-4298-a178-1ae3b617c5b9","type":"BasicTicker"}},"id":"f232acb0-92d4-4ad3-ada0-3df3e3b1b719","type":"Grid"},{"attributes":{},"id":"685d0129-66d2-45ab-b4e2-bc856bc087d2","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9bf13590-221c-4a75-bce0-c226fdbbc539","type":"PanTool"},{"id":"baee8ecd-7085-4020-a3d0-b26de7e5d942","type":"WheelZoomTool"}]},"id":"e762071f-2d28-4b6c-915d-4ae66d523782","type":"Toolbar"},{"attributes":{"formatter":{"id":"685d0129-66d2-45ab-b4e2-bc856bc087d2","type":"BasicTickFormatter"},"plot":{"id":"f6969e02-9934-497c-b97f-185b01bfff0c","subtype":"Figure","type":"Plot"},"ticker":{"id":"95a049ea-33f8-4851-aca6-ac6693040f03","type":"BasicTicker"},"visible":false},"id":"7aaffa65-b54a-427b-92b5-bfda64425813","type":"LinearAxis"},{"attributes":{"formatter":{"id":"cb20f7ab-a6cc-4ee0-b03f-b11381b8dac4","type":"BasicTickFormatter"},"plot":{"id":"f6969e02-9934-497c-b97f-185b01bfff0c","subtype":"Figure","type":"Plot"},"ticker":{"id":"05131b25-6073-4298-a178-1ae3b617c5b9","type":"BasicTicker"},"visible":false},"id":"95fc9f54-c7e9-4a22-8476-81de1ef9f784","type":"LinearAxis"},{"attributes":{},"id":"bdaf8f4a-fb8b-4476-a7cf-ae13106c9e5d","type":"ToolEvents"},{"attributes":{"attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://creativecommons.org/licenses/by-sa/3.0\">CC BY SA</a>.","url":"http://tile.stamen.com/terrain/{Z}/{X}/{Y}.png"},"id":"2003f9e4-6c98-4b5f-aec8-e4af46285119","type":"WMTSTileSource"},{"attributes":{"callback":null,"end":20000000,"start":-20000000},"id":"e227d73c-4489-456f-8825-735198ea1242","type":"Range1d"},{"attributes":{"dimension":1,"plot":{"id":"f6969e02-9934-497c-b97f-185b01bfff0c","subtype":"Figure","type":"Plot"},"ticker":{"id":"95a049ea-33f8-4851-aca6-ac6693040f03","type":"BasicTicker"}},"id":"bba5c94b-f32c-44f4-9c92-1f9519bf2c9b","type":"Grid"},{"attributes":{"plot":{"id":"f6969e02-9934-497c-b97f-185b01bfff0c","subtype":"Figure","type":"Plot"}},"id":"9bf13590-221c-4a75-bce0-c226fdbbc539","type":"PanTool"},{"attributes":{},"id":"95a049ea-33f8-4851-aca6-ac6693040f03","type":"BasicTicker"},{"attributes":{},"id":"05131b25-6073-4298-a178-1ae3b617c5b9","type":"BasicTicker"},{"attributes":{"callback":null,"end":20000000,"start":-20000000},"id":"14f990d0-70f0-4cbd-80d0-68df8cbe63a3","type":"Range1d"},{"attributes":{},"id":"cb20f7ab-a6cc-4ee0-b03f-b11381b8dac4","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"95fc9f54-c7e9-4a22-8476-81de1ef9f784","type":"LinearAxis"}],"left":[{"id":"7aaffa65-b54a-427b-92b5-bfda64425813","type":"LinearAxis"}],"renderers":[{"id":"95fc9f54-c7e9-4a22-8476-81de1ef9f784","type":"LinearAxis"},{"id":"f232acb0-92d4-4ad3-ada0-3df3e3b1b719","type":"Grid"},{"id":"7aaffa65-b54a-427b-92b5-bfda64425813","type":"LinearAxis"},{"id":"bba5c94b-f32c-44f4-9c92-1f9519bf2c9b","type":"Grid"},{"id":"f90ccc07-0955-45dd-8615-c6690948d80e","type":"TileRenderer"}],"title":{"id":"47dea282-e105-49f9-a4f2-4db515c3e3b0","type":"Title"},"tool_events":{"id":"bdaf8f4a-fb8b-4476-a7cf-ae13106c9e5d","type":"ToolEvents"},"toolbar":{"id":"e762071f-2d28-4b6c-915d-4ae66d523782","type":"Toolbar"},"x_range":{"id":"e227d73c-4489-456f-8825-735198ea1242","type":"Range1d"},"y_range":{"id":"14f990d0-70f0-4cbd-80d0-68df8cbe63a3","type":"Range1d"}},"id":"f6969e02-9934-497c-b97f-185b01bfff0c","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":null},"id":"4 ...
#             var render_items = [{"docid":"a37f7360-7888-4c10-ad22-750e32af28bc","elementid":"48d251a9-8782-4bf7-932f-0ddd5dc3627b","modelid":"f6969e02-9934-497c-b97f-185b01bfff0c","notebook_comms_target":"8aa73a8f-dd6c-4cc8-a217-46a994e91d84"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[117]</strong>&gt;</code></p>

# %% [markdown]
# or, alternatively, supply a URL to WMTSTileSource

# %%
from bokeh.tile_providers import WMTSTileSource

wikimap = WMTSTileSource(url='https://maps.wikimedia.org/osm-intl/{Z}/{X}/{Y}@2x.png')

# Create a figure with a really large extent
bound = 20000000 # meters
fig = figure(tools='pan, wheel_zoom', x_range=(-bound, bound), y_range=(-bound, bound))

# Hide the axis and add the map tile
fig.axis.visible = False
fig.add_tile(wikimap)

show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="
ickFormatter"},"plot":{"id":"d297989a-5c6f-4f68-a0f6-5968a66bd6da","subtype":"Figure","type":"Plot"},"ticker":{"id":"58d03815-f669-4e0f-b93e-965730a1399a","type":"BasicTicker"},"visible":false},"id":"5c7e8093-d288-4032-8258-ebbee42af761","type":"LinearAxis"},{"attributes":{},"id":"d0be6cae-ac82-44a7-b727-79b32e4f54b8","type":"BasicTicker"},{"attributes":{"plot":{"id":"d297989a-5c6f-4f68-a0f6-5968a66bd6da","subtype":"Figure","type":"Plot"}},"id":"577bb8af-841d-4c13-911a-576016af9a82","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"6b2dc899-9a5b-4b9d-94ce-693aba88a8eb","type":"BasicTickFormatter"},"plot":{"id":"d297989a-5c6f-4f68-a0f6-5968a66bd6da","subtype":"Figure","type":"Plot"},"ticker":{"id":"d0be6cae-ac82-44a7-b727-79b32e4f54b8","type":"BasicTicker"},"visible":false},"id":"49806f56-e7f2-4d56-a516-b71ee0571332","type":"LinearAxis"},{"attributes":{"plot":{"id":"d297989a-5c6f-4f68-a0f6-5968a66bd6da","subtype":"Figure","type":"Plot"},"ticker":{"id":"58d03815-f669-4e0f-b93e-965730a1399a","type":"BasicTicker"}},"id":"a956aaf5-db1c-4da6-8e3f-5ec13bb7e857","type":"Grid"},{"attributes":{},"id":"b0f613f9-de69-42e6-ae10-0b7d08cd722f","type":"BasicTickFormatter"},{"attributes":{},"id":"6b2dc899-9a5b-4b9d-94ce-693aba88a8eb","type":"BasicTickFormatter"},{"attributes":{"tile_source":{"id":"639d359f-dfe3-4b62-88ba-25d5ecae8fd5","type":"WMTSTileSource"}},"id":"9272cbc8-2cbe-4c53-942d-18b77a7cfc80","type":"TileRenderer"}],"root_ids":["d297989a-5c6f-4f68-a0f6-5968a66bd6da"]},"title":"Bokeh ...
#             var render_items = [{"docid":"1abda88a-1540-4854-ab30-78846530bd02","elementid":"3f7322d5-235b-4fb9-ad73-2a166292bb5f","modelid":"d297989a-5c6f-4f68-a0f6-5968a66bd6da","notebook_comms_target":"ed1c0da4-281f-402c-8894-b2c52299427e"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[118]</strong>&gt;</code></p>

# %% [markdown]
# ### Adding data to the map
# To add data to the map is as simple as plotting, for example, some circles to the right grid coordinates. Because the axis extent is really large, we also need really large circles and put the far enough apart to actually be able to see them. Let's put some circles on the equator:

# %%
# Create a figure with a really large extent
bound = 20000000 # meters
fig = figure(tools='pan, wheel_zoom', x_range=(-bound, bound), y_range=(-bound, bound))

# Hide the axis and add the map tile
fig.axis.visible = False
fig.add_tile(wikimap)

# Add some circles to the map
fig.circle([0,1000000,2000000,3000000],[0,0,0,0],radius=100000)

show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="ba41bf99-78ad-4469-8e53-3d3f4fc258d5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ba41bf99-78ad-4469-8e53-3d3f4fc258d5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ba41bf99-78ad-4469-8e53-3d3f4fc258d5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"583e9896-f620-4dea-bbd3-302d9dbe6105":{"roots":{"references":[{"attributes":{},"id":"7bd40598-4419-43ff-b3f2-5bdb3fdb1e92","type":"BasicTicker"},{"attributes":{"plot":{"id":"cb5b6c23-9234-45c2-9c55-fd835cb15899","subtype":"Figure","type":"Plot"}},"id":"628d9b52-afbd-4946-ba97-0d2d1331d8da","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":
"aa76fe95-89d4-41c9-8685-812d111a5eac","type":"BasicTickFormatter"},"plot":{"id":"cb5b6c23-9234-45c2-9c55-fd835cb15899","subtype":"Figure","type":"Plot"},"ticker":{"id":"7bd40598-4419-43ff-b3f2-5bdb3fdb1e92","type":"BasicTicker"},"visible":false},"id":"b27b0f3e-139e-4335-a1f6-5d7f5685dc01","type":"LinearAxis"},{"attributes":{"callback":null,"end":20000000,"start":-20000000},"id":"e9571011-9b41-4983-b732-c2986f88f47c","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"628d9b52-afbd-4946-ba97-0d2d1331d8da","type":"PanTool"},{"id":"d861de35-8f8a-4e1c-93e9-fa5fb6d48a4b","type":"WheelZoomTool"}]},"id":"20540af9-6acf-4e24-8c2d-5f8cd5f65f6d","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0 ...
#             var render_items = [{"docid":"583e9896-f620-4dea-bbd3-302d9dbe6105","elementid":"ba41bf99-78ad-4469-8e53-3d3f4fc258d5","modelid":"cb5b6c23-9234-45c2-9c55-fd835cb15899","notebook_comms_target":"5ae0f845-1b14-45f4-8fd1-49eaa06ec42c"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
# <p><code>&lt;Bokeh Notebook handle for <strong>In[119]</strong>&gt;</code></p>

# %% [markdown]
# ### Transforming your data to the web mercator coordinate system
# In order to visualize georeferenced data, it is necessary to know the exact coordinates in the appropriate projection, i.e. the web mercator projection. This can be done manually, or by using Cartopy. In both cases I'll asume the original data is in lat/lon coordinates.
#
# For the manual approach, I took the transformation function from [this link](http://philippjfr.com/work/work-in-progress/bokeh-maptiles/). I then use this function to set the extent of the map and plot a center point on it.

# %%
import numpy as np

# http://philippjfr.com/work/work-in-progress/bokeh-maptiles/
def toWebMercator(xLon, yLat):
    # Check if coordinate out of range for Latitude/Longitude
    if (np.abs(xLon) > 180) and (np.abs(yLat) > 90):
        return
 
    semimajorAxis = 6378137.0  # WGS84 spheriod semimajor axis
    east = xLon * 0.017453292519943295
    north = yLat * 0.017453292519943295
 
    northing = 3189068.5 * np.log((1.0 + np.sin(north)) / (1.0 - np.sin(north)))
    easting = semimajorAxis * east
 
    return easting, northing

l, b = toWebMercator(-5, 45)
r, t = toWebMercator(5, 60)
cx,cy = toWebMercator(0,52.5)

extents = (l, b, r, t)

fig = figure(tools='pan, wheel_zoom', x_range=(l,r), y_range=(b,t))
fig.axis.visible = False
fig.add_tile(wikimap)

# Add center point
fig.circle(cx,cy,radius=100000,color='firebrick')

show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="da13bc0e-044f-4240-97bb-b731af785c68"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("da13bc0e-044f-4240-97bb-b731af785c68");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'da13bc0e-044f-4240-97bb-b731af785c68' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ca111341-b2ec-41ad-813b-7fe5b2f99d8e":{"roots":{"references":[{"attributes":{},"id":"1ee4a8c1-82ce-4e0d-9306-9c931df187c4","type":"ToolEvents"},{"attributes":{"plot":{"id":"a2948f82-5c5a-4fda-97d3-ee0eb41fecd3","subtype":"Figure","type":"Plot"}},"id":"b553d84b-9775-4aba-b787-c3be7b0f3a7d","type":"WheelZoomTool"},{"attributes":{"tile_source":{"id":"639d359f-dfe3-4b62-88ba-25d5ecae8fd5","type":"WMTSTileSource"}},"id":"de12a5d9-3bed-4076-818d-80633068e1ce","type":"TileRenderer"},{"attributes":{"data_source":{"id":"5c0f749a-731f-4ddb-9053-6fbc365a892a","type":"ColumnDataSource"},"glyph":{"id":"acd7284f-245c-47d4-839d-b0ddd0c7ff31","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"
},{"attributes":{"fill_color":{"value":"firebrick"},"line_color":{"value":"firebrick"},"radius":{"units":"data","value":100000},"x":{"value":0.0},"y":{"value":6891041.723891586}},"id":"acd7284f-245c-47d4-839d-b0ddd0c7ff31","type":"Circle"},{"attributes":{"callback":null,"end":8399737.88981836,"start":5621521.486192066},"id":"e407d787-9cb4-4054-b80d-ecaeb7f83dc7","type":"Range1d"},{"attributes":{"plot":null,"text":null},"id":"7f3266a1-e818-4694-9563-9defdc2a783b","type":"Title"},{"attributes":{},"id":"02fb8550-92d1-4b65 ...
#             var render_items = [{"docid":"ca111341-b2ec-41ad-813b-7fe5b2f99d8e","elementid":"da13bc0e-044f-4240-97bb-b731af785c68","modelid":"a2948f82-5c5a-4fda-97d3-ee0eb41fecd3","notebook_comms_target":"0c6af9e9-693c-40b4-8a28-65f33bc46efe"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console
# <p><code>&lt;Bokeh Notebook handle for <strong>In[121]</strong>&gt;</code></p>

# %% [markdown]
# With cartopy, it is very easy to transform between coordinate systems. However, it took me some time to find out that there is actually a projection available for the web mercator projection under the name GOOGLE_MERCATOR. In Cartopy, the lat/lon coordinate system is called PlateCarree, so to transform between the two we use the following:

# %%
from cartopy import crs as ccrs
from bokeh.models import Range1d # an alternative way to define the axis extent, not sure what the difference is.

x1,y1 = -5,45
x2,y2 = 5,60

l,b = ccrs.GOOGLE_MERCATOR.transform_point(x1,y1,ccrs.PlateCarree())
r,t = ccrs.GOOGLE_MERCATOR.transform_point(x2,y2,ccrs.PlateCarree())
cx,cy = ccrs.GOOGLE_MERCATOR.transform_point(0,52.5,ccrs.PlateCarree())

fig = figure(tools='pan, wheel_zoom', x_range=Range1d(l,r), y_range=Range1d(b,t))
fig.axis.visible = False
fig.add_tile(wikimap)

# Add center point
fig.circle(cx,cy,radius=100000,color='firebrick')

show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="74f91a27-5997-41f3-8ffa-4cb9bb5050bf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("74f91a27-5997-41f3-8ffa-4cb9bb5050bf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '74f91a27-5997-41f3-8ffa-4cb9bb5050bf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"78325bf6-23c3-446e-87d4-c03065453261":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9d509e3f-d886-4804-9bd7-dc52aeaa2725","type":"PanTool"},{"id":"62b8cd20-22a7-4530-9094-65bf8fe50389","type":"WheelZoomTool"}]},"id":"83f77c49-d732-40d1-b1ba-d6e38aeb978e","type":"Toolbar"},{"attributes":{},"id":"a12f085e-dc87-4238-bf90-5aca338a2fa8","type":"ToolEvents"},{"attributes":{"plot":{"id":"261725a1-dd63-499d-a6c2-cd4960aad1fd","subtype":"Figure","type":"Plot"},"ticker":{"id":"dbaf7ad5-1320-4a80-802f-5d6f947c4d46","type":"BasicTicker"}},"id":"7c2970b5-5087-4e35-b8f6-8c28825ec3f3","type":"Grid"},{"attributes":{"plot":{"id":"261725a1-dd63-499d-a6c2-cd4960aad1fd","subtype":"Figure","type":"Plot"}},"id":"9d509e3f-d886-4804-9bd7-dc52aeaa2725","type":"PanTool"},{"attributes":{},"id":"5b523991-f6cd-46dc-96e8-cc9a4a3a4fa1","type":"BasicTicker"},{"attributes":{"callback":null,"end":8399737.889818355,"start":5621521.486192066},"id":"0ab4d0d8-08d8-45bc-859d-3101ea5ecac9","type":"Range1d"},{"attributes":{"formatter":{"id":"083153ae-0515-4b88-b3c8-1b0d56b17264","type":"BasicTickFormatter"},"plot":{"id":"261725a1-dd63-499d-a6c2-cd4960aad1fd","subtype":"Figure","type":"Plot"},"ticker":{"id":
}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         consol
# <p><code>&lt;Bokeh Notebook handle for <strong>In[124]</strong>&gt;</code></p>

# %% [markdown]
# I figured that it should also be possible to load the web-mercator projection into cartopy by using ccrs.epsg(3857), but it seems this redirects to the default mercator projection, so this does not work as I expected.

# %% [markdown]
# ### Loading some data from my WRF output
# Here I use the xarray package to quickly load some WRF data from my output. I will need latitude, longitude and some toy variable, for which I simply use T2. Note that I don't load all the points (600x600), but use every 10th point instead to save some memory.

# %%
import xarray as xr

wrfout = xr.open_dataset('wrfout_d01_2013-03-20_00:00:00')
lon = wrfout.XLONG.isel(Time=1).values[::10,::10]
lat = wrfout.XLAT.isel(Time=1).values[::10,::10]
T2 = wrfout.T2.isel(Time=1).values[::10,::10]

# %% [markdown]
# ### Plotting the data on a map
# Now, in matplotlib we have the possibility to plot 2-dimensional geographic data as contour lines, pcolormeshes, etc. This functionality is not (yet?) available for Bokeh, but a suitable alternative is to plot circles and color the according to their value. To this end, we convert the T2 array to an array with color codes (using matplotlib here for simplicity).
# Then, we use cartopy's convert_points function to get the right coordinates in web-mercator projection. Then, all we need to do is plot all the points on the map and we're done!

# %%
import matplotlib as mpl

# Transform T2 to color codes
colors = [
    "#%02x%02x%02x" % (int(r), int(g), int(b)) for r, g, b, _ in 255*mpl.cm.viridis(mpl.colors.Normalize()(T2.flatten()))
]

# Transform lat and lon to coordinates in web-mercator projection
points = ccrs.GOOGLE_MERCATOR.transform_points(ccrs.PlateCarree(),lon,lat)
x = points[:,:,0].flatten()
y = points[:,:,1].flatten()

# Make a figure, add the map
fig = figure(tools='pan, wheel_zoom', x_range=Range1d(l,r), y_range=Range1d(b,t))
fig.axis.visible = False
fig.add_tile(mapsource)

# Plot the points
fig.circle(x,y,color=colors)

fig.set(x_range = Range1d(l,r), y_range = Range1d(b,t))

show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9edac450-4d3e-4589-b909-b499ab360889"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9edac450-4d3e-4589-b909-b499ab360889");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9edac450-4d3e-4589-b909-b499ab360889' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"841ee0ac-5468-4032-b407-3ea3358c8cfa":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"f630d358-8569-42ac-8a60-e2b6c38261d1","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"07030c53-6b97-4c3c-9456-5fdf40e4a221","subtype":"Figure","type":"Plot"},"ticker":{"id":"992d20bf-0226-413e-9de7-8977ce260d72","type":"BasicTicker"}},"id":"e6f20c71-1969-4fa8-afbb-03faab9f2ee6","type":"Grid"},{"attributes":{"url":"https://maps.wikimedia.org/osm-intl/{Z}/{X}/{Y}@2x.png"},"id":"698574fa-286d-40de-ba35-7f9908d36976","type":"WMTSTileSource"},{"attributes":{},"id":"99fc695a-b017-4aee-96d4-e61b28b2252a","type":"BasicTickFormatter"},{"attributes":{},"id":"89704a2d-a1b1-4224-88be-1638d6aed7cf","type":"BasicTicker"},{"attributes":{"formatter":{"id":"99fc695a-b017-4aee-96d4-e61b28b2252a","type":"BasicTickFormatter"},"plot":{"id":"07030c53-6b97-4c3c-9456-5fdf40e4a221","subtype":"Figure","type":"Plot"},"ticker":{"id":"89704a2d-a1b1-4224-88be-1638d6aed7cf","type":"BasicTicker"},"visible":false},"id":"94251507-7517-4cb8-81e5-66b9587bccc7","type":"LinearAxis"},{"attributes":{"plot":{"id":"07030c53-6b97-4c3c-9456-5fdf40e4a221","subtype":"Figure","type":"Plot"}},"id":"eca81662-26d8-4d33-a825-e49b98429f66","type":"WheelZoomTool"},{"attributes":{"callback":null,"end